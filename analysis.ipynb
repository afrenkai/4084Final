# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_rus.zip.
# [nltk_data]    | Downloading package basque_grammars to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\maxent_treebank_pos_tagger_tab.zip.
# [nltk_data]    | Downloading package moses_sample to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data]    | Downloading package qc to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package tagsets_json to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets_json.zip.
# [nltk_data]    | Downloading package timit to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Artem Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to C:\Users\Artem
# [nltk_data]    |     Frenk\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pycaret/pycaret/master/datasets/amazon.csv')

# %%
df.head()
# Out:
#                                           reviewText  Positive
# 0  This is a one of the best apps acording to a b...         1
# 1  This is a pretty good version of the game for ...         1
# 2  this is a really cool game. there are a bunch ...         1
# 3  This is a silly game and can be frustrating, b...         1
# 4  This is a terrific game on any pad. Hrs of fun...         1

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    
    return scores

df['sentiment'] = df['reviewText'].apply(get_sentiment)
print(df['sentiment'])
# Out:
# 0        {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'comp...
# 1        {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'comp...
# 2        {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'comp...
# 3        {'neg': 0.062, 'neu': 0.41, 'pos': 0.528, 'com...
# 4        {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'comp...
#                                ...
# 19995    {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'comp...
# 19996    {'neg': 0.0, 'neu': 0.559, 'pos': 0.441, 'comp...
# 19997    {'neg': 0.0, 'neu': 0.405, 'pos': 0.595, 'comp...
# 19998    {'neg': 0.106, 'neu': 0.555, 'pos': 0.339, 'co...
# 19999    {'neg': 0.0, 'neu': 0.932, 'pos': 0.068, 'comp...
# Name: sentiment, Length: 20000, dtype: object

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    18003
# Neutral      1997
# Name: count, dtype: int64

# %%
def preprocess(text):
    tokens = word_tokenize(text.lower())
    filtered = [token for token in tokens if token not in stopwords.words('english')]
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered]
    processed_text = ''.join(lemmatized_tokens)
    return processed_text

df['reviewText'] = df['reviewText'].apply(preprocess)
df
# Out:
#                                               reviewText  Positive
# 0      onebestappsacordingbunchpeopleagreebombeggpigt...         1
# 1      prettygoodversiongamefree.lotdifferentlevelpla...         1
# 2       reallycoolgame.bunchlevelfindgoldenegg.superfun.         1
# 3      sillygamefrustrating,lotfundefinitelyrecommend...         1
# 4      terrificgamepad.hrfun.grandkidslove.greatenter...         1
# ...                                                  ...       ...
# 19995  appfrickenstupid.itfrozekindlewontallowplaceit...         0
# 19996  pleaseadd!!!!!needneighbor!ginger1016!!!!!!!!!...         1
# 19997  love!game.awesome.wishfreestuffhousen't.costmu...         1
# 19998  loveloveloveappsidefashionstoryfightwonderfula...         1
# 19999  gamerip.listthingmakebetter&bull;first,needrea...         0
#
# [20000 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(df['Positive'], df['sentiment']))

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    return scores

df['sentiment'] = df['reviewText'].apply(get_sentiment)
df
# Out:
#                                               reviewText  Positive  \
# 0      onebestappsacordingbunchpeopleagreebombeggpigt...         1
# 1      prettygoodversiongamefree.lotdifferentlevelpla...         1
# 2       reallycoolgame.bunchlevelfindgoldenegg.superfun.         1
# 3      sillygamefrustrating,lotfundefinitelyrecommend...         1
# 4      terrificgamepad.hrfun.grandkidslove.greatenter...         1
# ...                                                  ...       ...
# 19995  appfrickenstupid.itfrozekindlewontallowplaceit...         0
# 19996  pleaseadd!!!!!needneighbor!ginger1016!!!!!!!!!...         1
# 19997  love!game.awesome.wishfreestuffhousen't.costmu...         1
# 19998  loveloveloveappsidefashionstoryfightwonderfula...         1
# 19999  gamerip.listthingmakebetter&bull;first,needrea...         0
#
#                                                sentiment
# 0      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                  ...
# 19995  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19997  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19998  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19999  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [20000 rows x 3 columns]

# %%
from sklearn.metrics import classification_report

print(classification_report(df['Positive'], df['sentiment']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      1.00      0.38      4767
#            1       0.80      0.00      0.00     15233
#
#     accuracy                           0.24     20000
#    macro avg       0.52      0.50      0.19     20000
# weighted avg       0.67      0.24      0.09     20000
